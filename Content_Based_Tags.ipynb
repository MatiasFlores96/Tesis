# %%
# Imports
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
# Read dataframes
df_movies = pd.read_csv('ml-latest-small/movies.csv')
df_links = pd.read_csv('ml-latest-small/links.csv')
df_ratings = pd.read_csv('ml-latest-small/ratings.csv')
df_genome_tags = pd.read_csv('data/genome-tags.csv')
df_genome_scores = pd.read_csv('data/genome-scores.csv')

# Merge scores and tags
df_movie_tags_in_text = pd.merge(df_genome_scores, df_genome_tags, on='tagId')[['movieId', 'tag', 'relevance']]

# Only keep tags with relevance higher than 0.3
df_movie_tags = df_genome_scores[df_genome_scores.relevance > 0.3][['movieId', 'tagId']]

# %%
df_movie_tags
# Out:
#           movieId  tagId
# 10              1     11
# 18              1     19
# 20              1     21
# 21              1     22
# 28              1     29
# ...           ...    ...
# 14862490   187595   1091
# 14862491   187595   1092
# 14862495   187595   1096
# 14862500   187595   1101
# 14862513   187595   1114
#
# [1471046 rows x 2 columns]

# %%
df_movies[df_movies.movieId == 1]
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
df_movie_tags[df_movie_tags['movieId'] == 1].merge(df_genome_tags, on='tagId').sample(10)
# Out:
#      movieId  tagId                                    tag
# 161        1    982                               stylized
# 164        1    999                               suspense
# 107        1    602                        life philosophy
# 128        1    752  oscar (best effects - visual effects)
# 81         1    454                       good versus evil
# 176        1   1064                 unusual plot structure
# 24         1    193                                    cgi
# 53         1    353           enormously long battle scene
# 73         1    420                             futuristic
# 49         1    323                                  drama

# %%
df_tags_to_movies = pd.merge(df_movie_tags, df_genome_tags, on='tagId', how='left')[['movieId', 'tagId']]
df_tags_to_movies['tagId'] = df_tags_to_movies.tagId.astype(str)

# %%
df_tags_to_movies['tagId']
# Out:
# 0            11
# 1            19
# 2            21
# 3            22
# 4            29
#            ...
# 1471041    1091
# 1471042    1092
# 1471043    1096
# 1471044    1101
# 1471045    1114
# Name: tagId, Length: 1471046, dtype: object

# %%
def _concatenate_tags_of_movie(tags):
    tags_as_str = ' '.join(set(tags))
    return tags_as_str

# %%
df_tags_per_movie = df_tags_to_movies.groupby('movieId')['tagId'].agg(_concatenate_tags_of_movie)
df_tags_per_movie.name = 'movie_tags'
df_tags_per_movie = df_tags_per_movie.reset_index()

# %%
df_tags_per_movie
# Out:
#        movieId                                         movie_tags
# 0            1  11 338 445 719 29 33 323 371 675 61 368 21 951...
# 1            2  445 719 29 371 61 21 951 382 662 245 881 389 6...
# 2            3  777 865 445 505 1057 29 807 277 926 1102 292 1...
# 3            4  497 640 22 445 967 807 1116 299 439 128 179 21...
# 4            5  777 849 497 865 445 967 926 807 277 808 1102 1...
# ...        ...                                                ...
# 13171   185435  1123 445 926 21 100 389 333 335 1040 971 990 7...
# 13172   185585  777 886 332 719 29 807 277 889 933 982 1116 88...
# 13173   186587  177 338 45 426 323 887 951 929 100 536 353 333...
# 13174   187593  191 323 21 780 108 382 536 547 51 1040 311 797...
# 13175   187595  445 719 29 883 323 843 21 951 780 382 175 536 ...
#
# [13176 rows x 2 columns]

# %%
df_tags_per_movie[df_tags_per_movie['movieId'] == 1]
# Out:
#    movieId                                         movie_tags
# 0        1  11 338 445 719 29 33 323 371 675 61 368 21 951...

# %%
df_avg_ratings  = df_ratings.groupby('movieId')['rating'].agg(['mean', 'median', 'size'])
df_avg_ratings.columns = ['rating_mean', 'rating_median', 'num_ratingsdf_tags_per_movie']
df_avg_ratings = df_avg_ratings.reset_index()

# %%
df_avg_ratings
# Out:
#       movieId  rating_mean  rating_median  num_ratingsdf_tags_per_movie
# 0           1     3.920930            4.0                           215
# 1           2     3.431818            3.5                           110
# 2           3     3.259615            3.0                            52
# 3           4     2.357143            3.0                             7
# 4           5     3.071429            3.0                            49
# ...       ...          ...            ...                           ...
# 9719   193581     4.000000            4.0                             1
# 9720   193583     3.500000            3.5                             1
# 9721   193585     3.500000            3.5                             1
# 9722   193587     3.500000            3.5                             1
# 9723   193609     4.000000            4.0                             1
#
# [9724 rows x 4 columns]

# %%
df_movies_with_ratings = pd.merge(df_movies, df_avg_ratings, how='left', on='movieId')

# %%
df_movies_with_ratings
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  rating_mean  rating_median  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     3.920930            4.0
# 1                      Adventure|Children|Fantasy     3.431818            3.5
# 2                                  Comedy|Romance     3.259615            3.0
# 3                            Comedy|Drama|Romance     2.357143            3.0
# 4                                          Comedy     3.071429            3.0
# ...                                           ...          ...            ...
# 9737              Action|Animation|Comedy|Fantasy     4.000000            4.0
# 9738                     Animation|Comedy|Fantasy     3.500000            3.5
# 9739                                        Drama     3.500000            3.5
# 9740                             Action|Animation     3.500000            3.5
# 9741                                       Comedy     4.000000            4.0
#
#       num_ratingsdf_tags_per_movie
# 0                            215.0
# 1                            110.0
# 2                             52.0
# 3                              7.0
# 4                             49.0
# ...                            ...
# 9737                           1.0
# 9738                           1.0
# 9739                           1.0
# 9740                           1.0
# 9741                           1.0
#
# [9742 rows x 6 columns]

# %%
df_data = pd.merge(df_movies_with_ratings, df_tags_per_movie, how='left', on='movieId')

# %%
df_data
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  rating_mean  rating_median  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     3.920930            4.0
# 1                      Adventure|Children|Fantasy     3.431818            3.5
# 2                                  Comedy|Romance     3.259615            3.0
# 3                            Comedy|Drama|Romance     2.357143            3.0
# 4                                          Comedy     3.071429            3.0
# ...                                           ...          ...            ...
# 9737              Action|Animation|Comedy|Fantasy     4.000000            4.0
# 9738                     Animation|Comedy|Fantasy     3.500000            3.5
# 9739                                        Drama     3.500000            3.5
# 9740                             Action|Animation     3.500000            3.5
# 9741                                       Comedy     4.000000            4.0
#
#       num_ratingsdf_tags_per_movie  \
# 0                            215.0
# 1                            110.0
# 2                             52.0
# 3                              7.0
# 4                             49.0
# ...                            ...
# 9737                           1.0
# 9738                           1.0
# 9739                           1.0
# 9740                           1.0
# 9741                           1.0
#
#                                              movie_tags
# 0     11 338 445 719 29 33 323 371 675 61 368 21 951...
# 1     445 719 29 371 61 21 951 382 662 245 881 389 6...
# 2     777 865 445 505 1057 29 807 277 926 1102 292 1...
# 3     497 640 22 445 967 807 1116 299 439 128 179 21...
# 4     777 849 497 865 445 967 926 807 277 808 1102 1...
# ...                                                 ...
# 9737                                                NaN
# 9738                                                NaN
# 9739                                                NaN
# 9740                                                NaN
# 9741                                                NaN
#
# [9742 rows x 7 columns]

# %%
df_data_with_tags = df_data[~df_data.movie_tags.isnull()].reset_index(drop=True)

# %%
df_data_with_tags
# Out:
#       movieId                               title  \
# 0           1                    Toy Story (1995)
# 1           2                      Jumanji (1995)
# 2           3             Grumpier Old Men (1995)
# 3           4            Waiting to Exhale (1995)
# 4           5  Father of the Bride Part II (1995)
# ...       ...                                 ...
# 8741   185435              Game Over, Man! (2018)
# 8742   185585        Pacific Rim: Uprising (2018)
# 8743   186587                      Rampage (2018)
# 8744   187593                   Deadpool 2 (2018)
# 8745   187595      Solo: A Star Wars Story (2018)
#
#                                            genres  rating_mean  rating_median  \
# 0     Adventure|Animation|Children|Comedy|Fantasy     3.920930           4.00
# 1                      Adventure|Children|Fantasy     3.431818           3.50
# 2                                  Comedy|Romance     3.259615           3.00
# 3                            Comedy|Drama|Romance     2.357143           3.00
# 4                                          Comedy     3.071429           3.00
# ...                                           ...          ...            ...
# 8741                                Action|Comedy     3.000000           3.00
# 8742                        Action|Fantasy|Sci-Fi     2.750000           2.75
# 8743                      Action|Adventure|Sci-Fi     3.000000           3.00
# 8744                         Action|Comedy|Sci-Fi     3.875000           4.00
# 8745             Action|Adventure|Children|Sci-Fi     3.900000           4.00
#
#       num_ratingsdf_tags_per_movie  \
# 0                            215.0
# 1                            110.0
# 2                             52.0
# 3                              7.0
# 4                             49.0
# ...                            ...
# 8741                           1.0
# 8742                           2.0
# 8743                           1.0
# 8744                          12.0
# 8745                           5.0
#
#                                              movie_tags
# 0     11 338 445 719 29 33 323 371 675 61 368 21 951...
# 1     445 719 29 371 61 21 951 382 662 245 881 389 6...
# 2     777 865 445 505 1057 29 807 277 926 1102 292 1...
# 3     497 640 22 445 967 807 1116 299 439 128 179 21...
# 4     777 849 497 865 445 967 926 807 277 808 1102 1...
# ...                                                 ...
# 8741  1123 445 926 21 100 389 333 335 1040 971 990 7...
# 8742  777 886 332 719 29 807 277 889 933 982 1116 88...
# 8743  177 338 45 426 323 887 951 929 100 536 353 333...
# 8744  191 323 21 780 108 382 536 547 51 1040 311 797...
# 8745  445 719 29 883 323 843 21 951 780 382 175 536 ...
#
# [8746 rows x 7 columns]

# %%
tf_idf = TfidfVectorizer()

# %%
df_movies_tf_idf_described = tf_idf.fit_transform(df_data_with_tags.movie_tags)

# %%
m2m = cosine_similarity(df_movies_tf_idf_described)

# %%
df_movies_tf_idf_described.shape
# Out:
# (13176, 1119)

# %%
df_tfidf_m2m = pd.DataFrame(cosine_similarity(df_movies_tf_idf_described))

# %%
index_to_movie_id = df_data_with_tags['movieId']

# %%
df_tfidf_m2m.columns = [str(index_to_movie_id[int(col)]) for col in df_tfidf_m2m.columns]

# %%
df_tfidf_m2m.index = [index_to_movie_id[idx] for idx in df_tfidf_m2m.index]

# %%
df_tfidf_m2m.head()
# Out:
#           1         2         3         4         5         6         7  \
# 1  1.000000  0.359995  0.140584  0.163904  0.197146  0.267026  0.240104
# 2  0.359995  1.000000  0.116658  0.123059  0.119013  0.090835  0.215883
# 3  0.140584  0.116658  1.000000  0.192486  0.407801  0.090215  0.246536
# 4  0.163904  0.123059  0.192486  1.000000  0.278716  0.075740  0.334642
# 5  0.197146  0.119013  0.407801  0.278716  1.000000  0.085531  0.309019
#
#           8         9        10  ...    184987    184997    185029    185135  \
# 1  0.233925  0.075557  0.223134  ...  0.231415  0.323718  0.449159  0.415062
# 2  0.221415  0.167558  0.221940  ...  0.309822  0.231912  0.207119  0.253158
# 3  0.151995  0.077091  0.142224  ...  0.118169  0.198064  0.173156  0.146563
# 4  0.200485  0.049504  0.079378  ...  0.151011  0.195374  0.211978  0.181477
# 5  0.151632  0.067623  0.109039  ...  0.147010  0.264331  0.182410  0.163857
#
#      185425    185435    185585    186587    187593    187595
# 1  0.115754  0.126076  0.154487  0.238729  0.376306  0.339774
# 2  0.151519  0.122537  0.183769  0.244879  0.204680  0.287186
# 3  0.090056  0.131115  0.226738  0.147758  0.202069  0.204408
# 4  0.214305  0.168674  0.164492  0.162263  0.170269  0.199378
# 5  0.117392  0.133729  0.157140  0.148886  0.199741  0.162280
#
# [5 rows x 13176 columns]

# %%
df_tfidf_m2m.iloc[0].sort_values(ascending=False)[1:11]
# Out:
# 3114     0.785583
# 4886     0.773566
# 78499    0.747440
# 2355     0.728273
# 6377     0.705095
# 68954    0.668650
# 8961     0.660274
# 50872    0.653690
# 4306     0.652549
# 364      0.632700
# Name: 1, dtype: float64

# %%
df_data_with_tags[df_data_with_tags.movieId == 3114]
# Out:
#       movieId               title  \
# 2809     3114  Toy Story 2 (1999)
#
#                                            genres  rating_mean  rating_median  \
# 2809  Adventure|Animation|Children|Comedy|Fantasy     3.809977            4.0
#
#       num_ratingsdf_tags_per_movie  \
# 2809                       29820.0
#
#                                              movie_tags
# 2809  538 338 664 1114 519 743 472 19 244 777 62 61 ...

# %%
df_data_with_tags[df_data_with_tags.movieId == 4886]
# Out:
#       movieId                  title  \
# 4331     4886  Monsters, Inc. (2001)
#
#                                            genres  rating_mean  rating_median  \
# 4331  Adventure|Animation|Children|Comedy|Fantasy     3.861679            4.0
#
#       num_ratingsdf_tags_per_movie  \
# 4331                        8708.0
#
#                                              movie_tags
# 4331  216 215 669 664 663 765 136 497 490 493 690 10...

# %%
df_data_with_tags[df_data_with_tags.title.str.contains('Terminator 2')]
# Out:
#      movieId                              title         genres  rating_mean  \
# 555      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi     3.947648
#
#      rating_median  num_ratingsdf_tags_per_movie  \
# 555            4.0                       16093.0
#
#                                             movie_tags
# 555  216 768 215 212 1085 668 452 761 663 767 132 8...

# %%
df_tfidf_m2m.iloc[3114][555]
# Out:
# 0.06361854820409465

# %%
df_user_ratings = df_ratings[df_ratings.userId == 2000]

# %%
df_user_data_with_tags = df_data_with_tags.reset_index().merge(df_user_ratings, on='movieId')

# %%
df_user_data_with_tags[['title', 'rating']]
# Out:
#                                                  title  rating
# 0                                     Toy Story (1995)     4.0
# 1                                       Jumanji (1995)     3.5
# 2                Ace Ventura: When Nature Calls (1995)     1.0
# 3            Twelve Monkeys (a.k.a. 12 Monkeys) (1995)     4.0
# 4                                          Babe (1995)     3.5
# ..                                                 ...     ...
# 237  Star Wars: Episode VII - The Force Awakens (2015)     3.0
# 238                                 The Martian (2015)     3.0
# 239                                  Inside Out (2015)     4.0
# 240                                   Spotlight (2015)     4.5
# 241                              Big Short, The (2015)     4.5
#
# [242 rows x 2 columns]

# %%
df_user_data_with_tags['weight'] = df_user_data_with_tags['rating']/5.

# %%
df_user_data_with_tags
# Out:
#      index  movieId                                              title  \
# 0        0        1                                   Toy Story (1995)
# 1        1        2                                     Jumanji (1995)
# 2       18       19              Ace Ventura: When Nature Calls (1995)
# 3       31       32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 4       33       34                                        Babe (1995)
# ..     ...      ...                                                ...
# 237  12105   122886  Star Wars: Episode VII - The Force Awakens (2015)
# 238  12337   134130                                 The Martian (2015)
# 239  12357   134853                                  Inside Out (2015)
# 240  12526   142488                                   Spotlight (2015)
# 241  12625   148626                              Big Short, The (2015)
#
#                                                 genres  rating_mean  \
# 0          Adventure|Animation|Children|Comedy|Fantasy     3.886649
# 1                           Adventure|Children|Fantasy     3.246583
# 2                                               Comedy     2.642014
# 3                              Mystery|Sci-Fi|Thriller     3.890193
# 4                                       Children|Drama     3.613834
# ..                                                 ...          ...
# 237               Action|Adventure|Fantasy|Sci-Fi|IMAX     3.794736
# 238                             Adventure|Drama|Sci-Fi     4.043812
# 239  Adventure|Animation|Children|Comedy|Drama|Fantasy     3.960429
# 240                                           Thriller     4.079351
# 241                                              Drama     4.019956
#
#      rating_median  num_ratingsdf_tags_per_movie  \
# 0              4.0                       68469.0
# 1              3.0                       27143.0
# 2              3.0                       24913.0
# 3              4.0                       54846.0
# 4              4.0                       35903.0
# ..             ...                           ...
# 237            4.0                       12747.0
# 238            4.0                       16160.0
# 239            4.0                       13659.0
# 240            4.0                        5211.0
# 241            4.0                        6765.0
#
#                                             movie_tags  userId  rating  \
# 0    982 338 1093 664 830 990 1114 519 743 472 19 2...    2000     4.0
# 1    112 1093 396 1113 502 743 19 244 51 777 889 62...    2000     3.5
# 2    763 558 594 893 216 418 777 801 62 265 264 807...    2000     1.0
# 3    538 982 52 222 558 1093 243 396 547 46 715 830...    2000     4.0
# 4    338 46 1114 244 62 61 603 497 22 378 469 468 6...    2000     3.5
# ..                                                 ...     ...     ...
# 237  982 52 222 833 1005 338 850 1093 396 911 502 9...    2000     3.0
# 238  555 338 1093 243 396 46 830 945 1114 519 743 1...    2000     3.0
# 239  52 338 1093 664 46 871 1114 519 743 1024 216 4...    2000     4.0
# 240  982 833 262 555 558 338 850 243 715 567 682 11...    2000     4.5
# 241  982 52 558 555 338 243 567 1114 519 743 1024 4...    2000     4.5
#
#       timestamp  weight
# 0    1455860873     0.8
# 1    1456119319     0.7
# 2    1455861164     0.2
# 3    1455998568     0.8
# 4    1455861041     0.7
# ..          ...     ...
# 237  1455823417     0.6
# 238  1455999133     0.6
# 239  1455998854     0.8
# 240  1455823423     0.9
# 241  1455823419     0.9
#
# [242 rows x 12 columns]

# %%
user_profile = np.dot(df_movies_tf_idf_described[df_user_data_with_tags['index'].values].toarray().T, df_user_data_with_tags['weight'].values)

# %%
C = cosine_similarity(atleast_2d(user_profile), df_movies_tf_idf_described)

# %%
R = argsort(C)[:, ::-1]

# %%
recommendations = [i for i in R[0] if i not in df_user_data_with_tags['index'].values]

# %%
df_data_with_tags['title'][recommendations].head(10)
# Out:
# 13157                                 Isle of Dogs (2018)
# 12858                         Over the Garden Wall (2013)
# 13081                            Blade Runner 2049 (2017)
# 13106                                         Coco (2017)
# 12395          George Carlin: You Are All Diseased (1999)
# 1136                                   Stand by Me (1986)
# 13100    Three Billboards Outside Ebbing, Missouri (2017)
# 820                                 Apartment, The (1960)
# 13040             The Godfather Trilogy: 1972-1990 (1992)
# 12689                    Hunt for the Wilderpeople (2016)
# Name: title, dtype: object
